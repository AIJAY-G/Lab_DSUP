# %%
import matplotlib.pyplot as plt
number = [0.1,1.2,3,5,6,9,3.4,4.4]
plt.hist(number,bins=4,)
plt.xlabel("NUMBER")
plt.ylabel("FREQUENCY")
plt.show()

# %%
import matplotlib.pyplot as plt
labels=["js","java","py","c#"]
usage = [69,78.9,89.8,66]

y_pos =range(len(labels))

plt.bar(y_pos, usage)
plt.xticks(y_pos,labels)
plt.ylabel("usage (%)")
plt.title("PGM LAN usage")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import matplotlib.pyplot as plt
size = [23,34,45,30]
lables = ["cats","dogs","tiger","goat"]
plt.pie(size,labels = labels,autopct = "%.2f")
plt.show()
